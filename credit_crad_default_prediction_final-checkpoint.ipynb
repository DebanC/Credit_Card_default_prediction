# %%
import pandas as pd
import numpy as np
import matplotlib as mat
import matplotlib.pyplot as plt  
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv("UCI_Credit_Card.csv")

# %%
df.describe()
# Out:
#                  ID       LIMIT_BAL           SEX     EDUCATION      MARRIAGE  \
# count  30000.000000    30000.000000  30000.000000  30000.000000  30000.000000
# mean   15000.500000   167484.322667      1.603733      1.853133      1.551867
# std     8660.398374   129747.661567      0.489129      0.790349      0.521970
# min        1.000000    10000.000000      1.000000      0.000000      0.000000
# 25%     7500.750000    50000.000000      1.000000      1.000000      1.000000
# 50%    15000.500000   140000.000000      2.000000      2.000000      2.000000
# 75%    22500.250000   240000.000000      2.000000      2.000000      2.000000
# max    30000.000000  1000000.000000      2.000000      6.000000      3.000000
#
#                 AGE         PAY_0         PAY_2         PAY_3         PAY_4  \
# count  30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# mean      35.485500     -0.016700     -0.133767     -0.166200     -0.220667
# ...

# %% [markdown]
# Content There are 25 variables:
#
# ID: ID of each client
# LIMIT_BAL: Amount of given credit in NT dollars (includes individual and family/supplementary = credit)
# SEX: Gender (1=male, 2=female)
# EDUCATION: (1=graduate school, 2=university, 3=high school, 4=others, 5=unknown, 6=unknown)
# MARRIAGE: Marital status (1=married, 2=single, 3=others)
# AGE: Age in years
# PAY_0: Repayment status in September, 2005 (-1=pay duly, 1=payment delay for one month, 2=payment delay for two months, … 8=payment delay for eight months, 9=payment delay for nine months and above)
# PAY_2: Repayment status in August, 2005 (scale same as above)
# PAY_3: Repayment status in July, 2005 (scale same as above)
# PAY_4: Repayment status in June, 2005 (scale same as above)
# PAY_5: Repayment status in May, 2005 (scale same as above)
# PAY_6: Repayment status in April, 2005 (scale same as above)
# BILL_AMT1: Amount of bill statement in September, 2005 (NT dollar)
# BILL_AMT2: Amount of bill statement in August, 2005 (NT dollar)
# BILL_AMT3: Amount of bill statement in July, 2005 (NT dollar)
# BILL_AMT4: Amount of bill statement in June, 2005 (NT dollar)
# BILL_AMT5: Amount of bill statement in May, 2005 (NT dollar)
# BILL_AMT6: Amount of bill statement in April, 2005 (NT dollar)
# PAY_AMT1: Amount of previous payment in September, 2005 (NT dollar)
# PAY_AMT2: Amount of previous payment in August, 2005 (NT dollar)
# PAY_AMT3: Amount of previous payment in July, 2005 (NT dollar)
# PAY_AMT4: Amount of previous payment in June, 2005 (NT dollar)
# PAY_AMT5: Amount of previous payment in May, 2005 (NT dollar)
# PAY_AMT6: Amount of previous payment in April, 2005 (NT dollar)
# default.payment.next.month: Default payment (1=yes, 0=no)

# %% [markdown]
#
# df.isnull().sum()

# %% [markdown]
# There is no Missing Value in dataset

# %%
### To check duplicate values 
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# There are no duplicates values in the data set

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 25 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   ID                          30000 non-null  int64
#  1   LIMIT_BAL                   30000 non-null  float64
#  2   SEX                         30000 non-null  int64
#  3   EDUCATION                   30000 non-null  int64
#  4   MARRIAGE                    30000 non-null  int64
#  5   AGE                         30000 non-null  int64
#  6   PAY_0                       30000 non-null  int64
#  7   PAY_2                       30000 non-null  int64
#  8   PAY_3                       30000 non-null  int64
#  9   PAY_4                       30000 non-null  int64
#  10  PAY_5                       30000 non-null  int64
#  11  PAY_6                       30000 non-null  int64
#  12  BILL_AMT1                   30000 non-null  float64
# ...

# %%
df.nunique()
# Out:
# ID                            30000
# LIMIT_BAL                        81
# SEX                               2
# EDUCATION                         7
# MARRIAGE                          4
# AGE                              56
# PAY_0                            11
# PAY_2                            11
# PAY_3                            11
# PAY_4                            11
# PAY_5                            10
# PAY_6                            10
# BILL_AMT1                     22723
# BILL_AMT2                     22346
# BILL_AMT3                     22026
# BILL_AMT4                     21548
# BILL_AMT5                     21010
# BILL_AMT6                     20604
# PAY_AMT1                       7943
# PAY_AMT2                       7899
# PAY_AMT3                       7518
# PAY_AMT4                       6937
# PAY_AMT5                       6897
# PAY_AMT6                       6939
# default.payment.next.month        2
# dtype: int64

# %%
df.rename(columns = {'PAY_0':'PAY_1', 'default.payment.next.month':'Default'}, inplace = True)

# %% [markdown]
# For default column Default payment (1=yes, 0=no)

# %%
df.head()
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_1  PAY_2  PAY_3  PAY_4  \
# 0   1    20000.0    2          2         1   24      2      2     -1     -1
# 1   2   120000.0    2          2         2   26     -1      2      0      0
# 2   3    90000.0    2          2         2   34      0      0      0      0
# 3   4    50000.0    2          2         1   37      0      0      0      0
# 4   5    50000.0    1          2         1   57     -1      0     -1      0
#
#    ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0  ...        0.0        0.0        0.0       0.0     689.0       0.0
# 1  ...     3272.0     3455.0     3261.0       0.0    1000.0    1000.0
# 2  ...    14331.0    14948.0    15549.0    1518.0    1500.0    1000.0
# 3  ...    28314.0    28959.0    29547.0    2000.0    2019.0    1200.0
# 4  ...    20940.0    19146.0    19131.0    2000.0   36681.0   10000.0
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  Default
# 0       0.0       0.0       0.0        1
# ...

# %% [markdown]
# CAT : "SEX"

# %%
df['SEX'].value_counts()
# Out:
# 2    18112
# 1    11888
# Name: SEX, dtype: int64

# %% [markdown]
# SEX: Gender (1=male, 2=female)

# %% [markdown]
# No of Males= 11888 and No of Females=18112

# %%
df['Default'].groupby(df['SEX']).value_counts(normalize = True)
# Out:
# SEX  Default
# 1    0          0.758328
#      1          0.241672
# 2    0          0.792237
#      1          0.207763
# Name: Default, dtype: float64

# %%
plt.figure(figsize=(15,5))
cc = sns.countplot(data = df, x = 'SEX', hue="Default", palette = 'rocket')

plt.xlabel("Sex", fontsize= 12)
plt.ylabel("no of Clients", fontsize= 12)
plt.ylim(0,20000)
plt.xticks([0,1],['Male', 'Female'], fontsize = 11)

for p in cc.patches:
    cc.annotate((p.get_height()), (p.get_x()+0.16, p.get_height()+1000))

plt.show()

# %% [markdown]
#  An  indication that Mens have more chance of default than women

# %% [markdown]
# CAT : EDUCATION

# %%
df['EDUCATION'].value_counts()
# Out:
# 2    14030
# 1    10585
# 3     4917
# 5      280
# 4      123
# 6       51
# 0       14
# Name: EDUCATION, dtype: int64

# %% [markdown]
# EDUCATION: (1=graduate school, 2=university, 3=high school, 4=others, 5=unknown, 6=unknown)

# %%
df['Default'].groupby(df['EDUCATION']).value_counts(normalize = True)
# Out:
# EDUCATION  Default
# 0          0          1.000000
# 1          0          0.807652
#            1          0.192348
# 2          0          0.762651
#            1          0.237349
# 3          0          0.748424
#            1          0.251576
# 4          0          0.943089
#            1          0.056911
# 5          0          0.935714
#            1          0.064286
# 6          0          0.843137
#            1          0.156863
# Name: Default, dtype: float64

# %% [markdown]
# There some people in unknown category(0,5,6) so putting these in a same category name "UNKNOWN AS 5"

# %%
df['EDUCATION']=df['EDUCATION'].replace(0,5)
df['EDUCATION']=df['EDUCATION'].replace(6,5)

# %%
df['EDUCATION'].value_counts()
# Out:
# 2    14030
# 1    10585
# 3     4917
# 5      345
# 4      123
# Name: EDUCATION, dtype: int64

# %%
df['Default'].groupby(df['EDUCATION']).value_counts(normalize=True)
# Out:
# EDUCATION  Default
# 1          0          0.807652
#            1          0.192348
# 2          0          0.762651
#            1          0.237349
# 3          0          0.748424
#            1          0.251576
# 4          0          0.943089
#            1          0.056911
# 5          0          0.924638
#            1          0.075362
# Name: Default, dtype: float64

# %%
plt.figure(figsize=(12,4))

cc = sns.countplot(data = df, x = 'EDUCATION', hue="Default", palette = 'rocket')

plt.xlabel("Education", fontsize= 12)
plt.ylabel("no of Clients", fontsize= 12)
plt.ylim(0,15000)
plt.xticks([0,1,2,3,4],['Grad School','University','High School','Others','Unknown'], fontsize = 11)
 
for p in cc.patches:
    cc.annotate(f'{p.get_height():.0f}', (p.get_x() + 0.11, p.get_height() + 500), ha='center')

plt.show()

# %%
plt.figure(figsize=(12,4))

cc = sns.barplot(x = "EDUCATION", y = "Default", data = df, palette = 'rocket', ci = None)

plt.ylabel("% of Default", fontsize= 12)
plt.ylim(0,0.5)
plt.xticks([0,1,2,3,4],['Grad School','University','High School','Others','Unknown'], fontsize = 11)

for p in cc.patches:
    cc.annotate("{:.0%}".format(p.get_height()), (p.get_x() + 0.30, p.get_height() + 0.03), fontsize=13)



plt.show()

# %% [markdown]
# CAT : MARRIAGE

# %%
df['MARRIAGE'].value_counts()
# Out:
# 2    15964
# 1    13659
# 3      323
# 0       54
# Name: MARRIAGE, dtype: int64

# %% [markdown]
# MARRIAGE: Marital status (1=married, 2=single, 3=others)

# %%
df['MARRIAGE']=df['MARRIAGE'].replace(0,3)

# %%
df['MARRIAGE'].value_counts()
# Out:
# 2    15964
# 1    13659
# 3      377
# Name: MARRIAGE, dtype: int64

# %% [markdown]
# Unknown category had converted to others

# %%
plt.figure(figsize=(12,4))

cc = sns.countplot(data = df, x = 'MARRIAGE', hue="Default", palette = 'rocket')

plt.xlabel("Marital Status", fontsize= 12)
plt.ylabel("# of Clients", fontsize= 12)
plt.ylim(0,15000)
plt.xticks([0,1,2,],[ 'Married', 'Single', 'others'], fontsize = 11)

for p in cc.patches:
    cc.annotate((p.get_height()), (p.get_x()+0.10, p.get_height()+500))

plt.show()

# %%
plt.figure(figsize=(12,4))

cc = sns.barplot(x = "MARRIAGE", y = "Default", data = df, palette = 'rocket', ci = None)

plt.ylabel("% of Default", fontsize= 12)
plt.ylim(0,0.5)
plt.xticks([0,1,2],[ 'Married', 'Single', 'others'], fontsize = 11)

for p in cc.patches:
    cc.annotate("%.2f" %(p.get_height()), (p.get_x()+0.30, p.get_height()+0.03),fontsize=13)

plt.show()

# %% [markdown]
# Most people fall either "MARRIE" or "UNMARRIED" side.
# And the rest who are Others has slightly  higher default people

# %% [markdown]
# CAT : AGE

# %%
plt.figure(figsize=(12,4))

sns.distplot(df['AGE'])
plt.ticklabel_format(style='plain', axis='x')  
plt.ylabel("")
plt.show()

# %%
plt.figure(figsize=(12,4))

sns.kdeplot(df.loc[(df['Default'] == 0), 'AGE'], label = 'No Default', shade = True)
sns.kdeplot(df.loc[(df['Default'] == 1), 'AGE'], label = 'Default', shade = True)
plt.ylabel('')
plt.legend()
plt.show()

# %% [markdown]
# Most people are avobe dataset are within 20 to 40 (APPRX) BUt surprisingly the chances of default people in this bandwidth are less.

# %%
df['Agegrp'] = pd.cut(df['AGE'],[20, 25, 30, 35, 40, 50, 60, 80])
print(df['Agegrp'].value_counts())
# Out:
# (25, 30]    7142
# (40, 50]    6005
# (30, 35]    5796
# (35, 40]    4917
# (20, 25]    3871
# (50, 60]    1997
# (60, 80]     272
# Name: Agegrp, dtype: int64

# %%
df.head(2)
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_1  PAY_2  PAY_3  PAY_4  \
# 0   1    20000.0    2          2         1   24      2      2     -1     -1
# 1   2   120000.0    2          2         2   26     -1      2      0      0
#
#    ...  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  PAY_AMT4  \
# 0  ...        0.0        0.0       0.0     689.0       0.0       0.0
# 1  ...     3455.0     3261.0       0.0    1000.0    1000.0    1000.0
#
#    PAY_AMT5  PAY_AMT6  Default    Agegrp
# 0       0.0       0.0        1  (20, 25]
# 1       0.0    2000.0        1  (25, 30]
#
# [2 rows x 26 columns]

# %%
plt.figure(figsize=(12,4))

df['Agegrp'] = df['Agegrp'].astype('str')
Agegrp_order = ['(20, 25]', '(25, 30]', '(30, 35]', '(35, 40]', '(40, 50]', '(50, 60]', '(60, 80]']

cc = sns.countplot(data = df, x = 'Agegrp', hue="Default", palette = 'rocket', order = Agegrp_order)

plt.xlabel("Age Group", fontsize= 12)
plt.ylabel("# of Clients", fontsize= 12)
plt.ylim(0,10000)

for p in cc.patches:
    cc.annotate((p.get_height()), (p.get_x()+0.075, p.get_height()+300))

plt.show()

# %%
plt.figure(figsize=(10,3))

cc= sns.barplot(x = "Agegrp", y = "Default", data = df, palette = 'rocket', ci = None, order = Agegrp_order)

plt.xlabel("Age Group", fontsize= 12)
plt.ylabel("% of Default", fontsize= 12)
plt.ylim(0,0.5)

for p in cc.patches:
    cc.annotate("%.2f" %(p.get_height()), (p.get_x()+0.25, p.get_height()+0.03),fontsize=10)

plt.show()

# %% [markdown]
# The people in range between 20-25 years and 60-80 years have higher chance of default.
# And the lowest chance of default are in age group of 30-35 .

# %% [markdown]
# CAT : CREDIT (LIMIT_BAL)

# %%
plt.figure(figsize=(12,5))

sns.kdeplot(df.loc[(df['Default'] == 0), 'LIMIT_BAL'], label = 'No Default', shade = True)
sns.kdeplot(df.loc[(df['Default'] == 1), 'LIMIT_BAL'], label = 'Default', shade = True)
plt.ticklabel_format(style='plain', axis='x') 
plt.ylabel('')
plt.legend()
plt.show()

# %% [markdown]
# Most people have Credit limit 200k or less and also we find the huge default cases in this range.

# %%
df['Limitrange'] = pd.cut(df['LIMIT_BAL'],[5000, 50000, 100000, 150000, 200000, 300000, 400000, 500000, 1100000])
print(df['Limitrange'].value_counts())
# Out:
# (5000, 50000]        7676
# (200000, 300000]     5059
# (50000, 100000]      4822
# (150000, 200000]     3978
# (100000, 150000]     3902
# (300000, 400000]     2759
# (400000, 500000]     1598
# (500000, 1100000]     206
# Name: Limitrange, dtype: int64

# %%
plt.figure(figsize=(16,5))

df['Limitrange'] = df['Limitrange'].astype('str')
Limitrange_order = ['(5000, 50000]', '(50000, 100000]', '(100000, 150000]', '(150000, 200000]',
                '(200000, 300000]', '(300000, 400000]', '(400000, 500000]', '(500000, 1100000]']

cc = sns.countplot(data = df, x = 'Limitrange', hue="Default", palette = 'rocket', order = Limitrange_order)

plt.xlabel("Amount of Given Credit", fontsize= 12)
plt.ylabel("# of Clients", fontsize= 12)
plt.ylim(0,8000)
cc.tick_params(axis="x", labelsize= 9.5)

for p in cc.patches:
    cc.annotate((p.get_height()), (p.get_x()+0.075, p.get_height()+300))

plt.show()

# %%
plt.figure(figsize=(14,4))

cc = sns.barplot(x = "Limitrange", y = "Default", data = df, palette = 'rocket', ci = None, order = Limitrange_order)

plt.xlabel("Amount of Given Credit", fontsize= 12)
plt.ylabel("% of Default", fontsize= 12)
plt.ylim(0,0.5)

for p in cc.patches:
    cc.annotate("%.2f" %(p.get_height()), (p.get_x()+0.25, p.get_height()+0.03),fontsize=13)

plt.show()

# %% [markdown]
# After analysis we can see higher the credit limit and lower is the chance of defaulting. It's quite evidend that above 30% of people who's credit limit is 50k or less have higher default rate.

# %% [markdown]
# CAT : LIMIT_BAL with DEMOGRAPHIC feature

# %%
plt.figure(figsize=(10,5))

sns.boxplot(x = "SEX", y = "LIMIT_BAL",data = df, palette = 'rocket', showmeans=True, 
            meanprops={"markerfacecolor":"red",  "markeredgecolor":"black", "markersize":"10"})

plt.ticklabel_format(style='plain', axis='y')  
plt.xticks([0,1],['Male', 'Female'], fontsize = 12)

plt.show()

# %%
 
df.groupby('EDUCATION')['LIMIT_BAL'].mean()
# Out:
# EDUCATION
# 1    212956.069910
# 2    147062.437634
# 3    126550.270490
# 4    220894.308943
# 5    167205.797101
# Name: LIMIT_BAL, dtype: float64

# %%
plt.figure(figsize=(14,6))

sns.boxplot(x = "EDUCATION", y = "LIMIT_BAL", data = df, palette = 'rocket', showmeans=True, 
            meanprops={"markerfacecolor":"red",  "markeredgecolor":"black", "markersize":"10"})

plt.ticklabel_format(style='plain', axis='y') #repressing scientific notation   
plt.xticks([0,1,2,3,4],['Grad School','University','High School','Others','Unknown'], fontsize = 11)

plt.show()

# %%
df.groupby('MARRIAGE')['LIMIT_BAL'].mean()
# Out:
# MARRIAGE
# 1    182200.893184
# 2    156413.660737
# 3    103076.923077
# Name: LIMIT_BAL, dtype: float64

# %%
plt.figure(figsize=(14,6))

sns.boxplot(x = "MARRIAGE", y = "LIMIT_BAL", data = df, palette = 'rocket', showmeans=True, 
            meanprops={"markerfacecolor":"red",  "markeredgecolor":"black", "markersize":"10"})

plt.ticklabel_format(style='plain', axis='y')     
plt.xticks([0,1,2],[ 'Married', 'Single', 'others'], fontsize = 11)

plt.show()

# %%
plt.figure(figsize=(14,6))

sns.boxplot(x = "Agegrp", y = "LIMIT_BAL",data = df, palette = 'rocket', order = Agegrp_order, showmeans=True, 
            meanprops={"markerfacecolor":"red",  "markeredgecolor":"black", "markersize":"10"})

plt.ticklabel_format(style='plain', axis='y')    
plt.xlabel("Age Group", fontsize= 12)

plt.show()

# %% [markdown]
# The exceptions are the unknown categories, which have lower chances of default.

# %%
plt.figure(figsize=(16,8))

sns.boxplot(x = "EDUCATION", y = "LIMIT_BAL", hue = 'SEX', data = df, palette = 'rocket', showmeans=True, 
            meanprops={"markerfacecolor":"green",  "markeredgecolor":"black", "markersize":"10"})

plt.ticklabel_format(style='plain', axis='y')   
plt.xticks([0,1,2,3,4],['Grad School','University','High School','Others','Unknown'], fontsize = 11)

plt.show()

# %%
plt.figure(figsize=(18,8))

sns.boxplot(x = "MARRIAGE", y = "LIMIT_BAL", hue = 'SEX', data = df, palette = 'rocket', showmeans=True, 
            meanprops={"markerfacecolor":"green",  "markeredgecolor":"black", "markersize":"12"})

plt.ticklabel_format(style='plain', axis='y')    
plt.xticks([0,1,2,],[ 'Married', 'Single', 'others'], fontsize = 11)

plt.show()

# %%
plt.figure(figsize=(15,6))

sns.boxplot(x = "Agegrp", y = "LIMIT_BAL", hue = 'SEX', data = df, palette = 'rocket', order = Agegrp_order, showmeans=True, 
            meanprops={"markerfacecolor":"red",  "markeredgecolor":"black", "markersize":"11"})

plt.ticklabel_format(style='plain', axis='y')     
plt.xlabel("Age Group", fontsize= 14)

plt.show()

# %% [raw]
# Content There are 25 variables:
#
# ID: ID of each client
# LIMIT_BAL: Amount of given credit in NT dollars (includes individual and family/supplementary = credit)
# SEX: Gender (1=male, 2=female)
# EDUCATION: (1=graduate school, 2=university, 3=high school, 4=others, 5=unknown, 6=unknown)
# MARRIAGE: Marital status (1=married, 2=single, 3=others)
# AGE: Age in years
# PAY_0: Repayment status in September, 2005 (-1=pay duly, 1=payment delay for one month, 2=payment delay for two months, … 8=payment delay for eight months, 9=payment delay for nine months and above)
# PAY_2: Repayment status in August, 2005 (scale same as above)
# PAY_3: Repayment status in July, 2005 (scale same as above)
# PAY_4: Repayment status in June, 2005 (scale same as above)
# PAY_5: Repayment status in May, 2005 (scale same as above)
# PAY_6: Repayment status in April, 2005 (scale same as above)
# BILL_AMT1: Amount of bill statement in September, 2005 (NT dollar)
# BILL_AMT2: Amount of bill statement in August, 2005 (NT dollar)
# BILL_AMT3: Amount of bill statement in July, 2005 (NT dollar)
# BILL_AMT4: Amount of bill statement in June, 2005 (NT dollar)
# BILL_AMT5: Amount of bill statement in May, 2005 (NT dollar)
# BILL_AMT6: Amount of bill statement in April, 2005 (NT dollar)
# PAY_AMT1: Amount of previous payment in September, 2005 (NT dollar)
# PAY_AMT2: Amount of previous payment in August, 2005 (NT dollar)
# PAY_AMT3: Amount of previous payment in July, 2005 (NT dollar)
# PAY_AMT4: Amount of previous payment in June, 2005 (NT dollar)
# PAY_AMT5: Amount of previous payment in May, 2005 (NT dollar)
# PAY_AMT6: Amount of previous payment in April, 2005 (NT dollar)
# default.payment.next.month: Default payment (1=yes, 0=no)

# %% [markdown]
# CAT : REPAYMENT STATUS (MONTHWISE)

# %%
pay_x_cols= ['PAY_1', 'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6']
plt.figure(figsize=(15,12))

for i,col in enumerate(pay_x_cols):    
    plt.subplot(3,2,i + 1)
    cc = sns.countplot(df.loc[:,col], palette = 'rocket')
    plt.ylim(0,20000)
    plt.ylabel('')
    plt.tight_layout()
    
    for p in cc.patches:
        cc.annotate((p.get_height()), (p.get_x()+0.08, p.get_height()+500), fontsize = 11)

plt.show()

# %%
plt.figure(figsize=(15,12))

for i,col in enumerate(pay_x_cols):    
    plt.subplot(3,2,i + 1)
    cc = sns.barplot(x = col, y = "Default", data = df, palette = 'rocket', ci = None)
    plt.ylabel("% of Default", fontsize= 12)
    plt.ylim(0,1.2)
    plt.tight_layout()
    
    for p in cc.patches:
        cc.annotate("%.2f" %(p.get_height()), (p.get_x()+0.09, p.get_height()+0.03),fontsize=13)

plt.show()

# %% [markdown]
# It is clear that most of the people are paying credit bills on time and chances of default are much lower than others.
# But there are few number of people who have more than equal to 4 months of delay have high chance of default.

# %% [markdown]
# Now we are making a new operation with them all together just to have the average default of a more significant group.

# %%
df['PAY_1_new'] = df['PAY_1'].copy()
df['PAY_2_new'] = df['PAY_2'].copy()
df['PAY_3_new'] = df['PAY_3'].copy()
df['PAY_4_new'] = df['PAY_4'].copy()
df['PAY_5_new'] = df['PAY_5'].copy()
df['PAY_6_new'] = df['PAY_6'].copy()

# %%
pay_x_newcol = ['PAY_1_new', 'PAY_2_new', 'PAY_3_new', 'PAY_4_new', 'PAY_5_new', 'PAY_6_new']

for col in pay_x_newcol:  
    df.loc[:,col] = df.loc[:,col].replace(5,4)
    df.loc[:,col] = df.loc[:,col].replace(6,4)
    df.loc[:,col] = df.loc[:,col].replace(7,4)
    df.loc[:,col] = df.loc[:,col].replace(8,4)
plt.figure(figsize=(15,12))

# %%
plt.figure(figsize=(15,8))

for i,col in enumerate(pay_x_newcol):    
    plt.subplot(3,2,i + 1)
    cc = sns.countplot(data = df, x = col, palette = 'rocket')
    plt.ylim(0,20000)
    plt.ylabel('')
    plt.tight_layout()
    
    for p in cc.patches:
        cc.annotate((p.get_height()), (p.get_x()+0.180, p.get_height()+700), fontsize = 11)

plt.show()

# %%
plt.figure(figsize=(15,8))

for i,col in enumerate(pay_x_newcol):    
    plt.subplot(3,2,i + 1)
    cc = sns.barplot(x = col, y = "Default", data = df, palette = 'rocket', ci = None)
    plt.ylabel("% of Default", fontsize= 12)
    plt.ylim(0,1.0)
    plt.tight_layout()
    
    for p in cc.patches:
        cc.annotate("%.2f" %(p.get_height()), (p.get_x()+0.20, p.get_height()+0.03),fontsize=13)

plt.show()

# %%
df.head()
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_1  PAY_2  PAY_3  PAY_4  \
# 0   1    20000.0    2          2         1   24      2      2     -1     -1
# 1   2   120000.0    2          2         2   26     -1      2      0      0
# 2   3    90000.0    2          2         2   34      0      0      0      0
# 3   4    50000.0    2          2         1   37      0      0      0      0
# 4   5    50000.0    1          2         1   57     -1      0     -1      0
#
#    ...  PAY_AMT6  Default    Agegrp        Limitrange  PAY_1_new  PAY_2_new  \
# 0  ...       0.0        1  (20, 25]     (5000, 50000]          2          2
# 1  ...    2000.0        1  (25, 30]  (100000, 150000]         -1          2
# 2  ...    5000.0        0  (30, 35]   (50000, 100000]          0          0
# 3  ...    1000.0        0  (35, 40]     (5000, 50000]          0          0
# 4  ...     679.0        0  (50, 60]     (5000, 50000]         -1          0
#
#    PAY_3_new  PAY_4_new  PAY_5_new  PAY_6_new
# ...

# %% [markdown]
# CAT: AMOUNT OF BILL STATEMENT

# %%
bill_amt_cols = ['BILL_AMT1', 'BILL_AMT2', 'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6']
plt.figure(figsize=(15,8))

for i,col in enumerate(bill_amt_cols):    
    plt.subplot(3,2,i + 1)
    sns.distplot(df.loc[:,col])
    plt.ticklabel_format(style='plain', axis='x')  
    plt.ylabel('')
    plt.tight_layout()

plt.show()

# %%
plt.figure(figsize=(18,10))

for i,col in enumerate(bill_amt_cols):    
    plt.subplot(3,2,i + 1)    
    sns.kdeplot(df.loc[(df['Default'] == 0), col], label = 'No Default', shade = True)
    sns.kdeplot(df.loc[(df['Default'] == 1), col], label = 'Default', shade = True)
    plt.xlim(-50000,200000)
    plt.ylabel('')
    plt.legend()
    plt.tight_layout()

plt.show()

# %%
df['BILL_AMT1_new'] = df['BILL_AMT1'].copy()
df['BILL_AMT2_new'] = df['BILL_AMT2'].copy()
df['BILL_AMT3_new'] = df['BILL_AMT3'].copy()
df['BILL_AMT4_new'] = df['BILL_AMT4'].copy()
df['BILL_AMT5_new'] = df['BILL_AMT5'].copy()
df['BILL_AMT6_new'] = df['BILL_AMT6'].copy()

# %%
bill_amt_new = ['BILL_AMT1_new', 'BILL_AMT2_new', 'BILL_AMT3_new', 'BILL_AMT4_new', 'BILL_AMT5_new', 'BILL_AMT6_new']

for i, col in enumerate (bill_amt_new):
    df[col] = pd.cut(df[bill_amt_new[i]],[-350000,-1,0,25000, 75000, 200000, 2000000])
    print(df[col].value_counts())
# Out:
# (0, 25000]           12965
# (25000, 75000]        7656
# (75000, 200000]       5258
# (-1, 0]               2008
# (200000, 2000000]     1523
# (-350000, -1]          590
# Name: BILL_AMT1_new, dtype: int64
# (0, 25000]           12647
# (25000, 75000]        7692
# (75000, 200000]       5094
# (-1, 0]               2506
# (200000, 2000000]     1392
# (-350000, -1]          669
# Name: BILL_AMT2_new, dtype: int64
# (0, 25000]           12696
# (25000, 75000]        7635
# (75000, 200000]       4888
# (-1, 0]               2870
# (200000, 2000000]     1256
# (-350000, -1]          655
# Name: BILL_AMT3_new, dtype: int64
# (0, 25000]           13081
# (25000, 75000]        7401
# (75000, 200000]       4623
# (-1, 0]               3195
# (200000, 2000000]     1025
# (-350000, -1]          675
# Name: BILL_AMT4_new, dtype: int64
# (0, 25000]           13401
# (25000, 75000]        7163
# (75000, 200000]       4399
# (-1, 0]               3506
# (200000, 2000000]      876
# ...

# %%
for col in bill_amt_new:
    print(df['Default'].groupby(df[col]).value_counts(normalize = True))
# Out:
# BILL_AMT1_new      Default
# (-350000, -1]      0          0.815254
#                    1          0.184746
# (-1, 0]            0          0.734064
#                    1          0.265936
# (0, 25000]         0          0.774470
#                    1          0.225530
# (25000, 75000]     0          0.775209
#                    1          0.224791
# (75000, 200000]    0          0.802396
#                    1          0.197604
# (200000, 2000000]  0          0.797111
#                    1          0.202889
# Name: Default, dtype: float64
# BILL_AMT2_new      Default
# (-350000, -1]      0          0.810164
#                    1          0.189836
# (-1, 0]            0          0.753791
#                    1          0.246209
# (0, 25000]         0          0.775836
#                    1          0.224164
# (25000, 75000]     0          0.773531
#                    1          0.226469
# (75000, 200000]    0          0.799176
#                    1          0.200824
# ...

# %%
plt.figure(figsize=(14,14))
for i,col in enumerate(bill_amt_new):    
    plt.subplot(3,2,i + 1)
    cc = sns.countplot(data = df, x = col, hue="Default", palette = 'rocket')
    plt.ylim(0,20000)
    plt.ylabel('')
    plt.xticks([0,1,2,3,4,5],['0 <', '= 0', '0-25k', '25k-75k', '75k-200k', '>200k'], fontsize = 10)
    plt.tight_layout()

    for p in cc.patches:
        cc.annotate((p.get_height()), (p.get_x()+0.04, p.get_height()+700), fontsize = 11)    
        
plt.show()

# %%
plt.figure(figsize=(15,12))

for i,col in enumerate(bill_amt_new):    
    plt.subplot(3,2,i + 1)
    cc = sns.barplot(x = col, y = "Default", data = df, palette = 'rocket', ci = None)
    plt.ylabel("% of Default", fontsize= 12)
    plt.ylim(0,0.5)
    plt.xticks([0,1,2,3,4,5],['0 <', '= 0', '0-25k', '25k-75k', '75k-200k', '>200k'], fontsize = 11)    
    plt.tight_layout()
    
    for p in cc.patches:
        cc.annotate("%.2f" %(p.get_height()), (p.get_x()+0.21, p.get_height()+0.03),fontsize=13)

plt.show()

# %% [markdown]
# The negetive bill amount has lower chances of default. People have outstanding bill amounts have higher chnces of default.

# %% [markdown]
# CAT : AMOUNT OF PREVIOUS STATEMENT

# %%
pay_amt_cols = ['PAY_AMT1', 'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6']
plt.figure(figsize=(14,10))

for i,col in enumerate(pay_amt_cols):    
    plt.subplot(3,2,i + 1)
    sns.distplot(df.loc[:,col])
    plt.ticklabel_format(style='plain', axis='x') 
    plt.ylabel('')
    plt.tight_layout()

plt.show()

# %%
plt.figure(figsize=(15,12))

for i,col in enumerate(pay_amt_cols):    
    plt.subplot(3,2,i + 1)    
    sns.kdeplot(df.loc[(df['Default'] == 0), col], label = 'No Default', shade = True)
    sns.kdeplot(df.loc[(df['Default'] == 1), col], label = 'Default', shade = True)
    plt.xlim(0,100000)
    plt.ylabel('')
    plt.legend()
    plt.tight_layout()

plt.show()

# %%
df['PAY_AMT1_new'] = df['PAY_AMT1'].copy()
df['PAY_AMT2_new'] = df['PAY_AMT2'].copy()
df['PAY_AMT3_new'] = df['PAY_AMT3'].copy()
df['PAY_AMT4_new'] = df['PAY_AMT4'].copy()
df['PAY_AMT5_new'] = df['PAY_AMT5'].copy()
df['PAY_AMT6_new'] = df['PAY_AMT6'].copy()

# %%
pay_amt_cols = ['PAY_AMT1_new', 'PAY_AMT2_new', 'PAY_AMT3_new', 'PAY_AMT4_new', 'PAY_AMT5_new', 'PAY_AMT6_new']

for i, col in enumerate (pay_amt_cols):
    df[col] = pd.cut(df[pay_amt_cols[i]],[-1, 0, 25000, 50000, 100000, 2000000])
    print(df[col].value_counts())
# Out:
# (0, 25000]           23730
# (-1, 0]               5249
# (25000, 50000]         550
# (50000, 100000]        322
# (100000, 2000000]      149
# Name: PAY_AMT1_new, dtype: int64
# (0, 25000]           23569
# (-1, 0]               5396
# (25000, 50000]         556
# (50000, 100000]        283
# (100000, 2000000]      196
# Name: PAY_AMT2_new, dtype: int64
# (0, 25000]           23068
# (-1, 0]               5968
# (25000, 50000]         514
# (50000, 100000]        273
# (100000, 2000000]      177
# Name: PAY_AMT3_new, dtype: int64
# (0, 25000]           22641
# (-1, 0]               6408
# (25000, 50000]         533
# (50000, 100000]        271
# (100000, 2000000]      147
# Name: PAY_AMT4_new, dtype: int64
# (0, 25000]           22382
# (-1, 0]               6703
# (25000, 50000]         493
# (50000, 100000]        268
# (100000, 2000000]      154
# Name: PAY_AMT5_new, dtype: int64
# (0, 25000]           21785
# (-1, 0]               7173
# (25000, 50000]         517
# ...

# %%
for col in pay_amt_cols:
    print(df['Default'].groupby(df[col]).value_counts(normalize = True))
# Out:
# PAY_AMT1_new       Default
# (-1, 0]            0          0.640503
#                    1          0.359497
# (0, 25000]         0          0.803582
#                    1          0.196418
# (25000, 50000]     0          0.910909
#                    1          0.089091
# (50000, 100000]    0          0.919255
#                    1          0.080745
# (100000, 2000000]  0          0.912752
#                    1          0.087248
# Name: Default, dtype: float64
# PAY_AMT2_new       Default
# (-1, 0]            0          0.666605
#                    1          0.333395
# (0, 25000]         0          0.797997
#                    1          0.202003
# (25000, 50000]     0          0.926259
#                    1          0.073741
# (50000, 100000]    0          0.936396
#                    1          0.063604
# (100000, 2000000]  0          0.913265
#                    1          0.086735
# Name: Default, dtype: float64
# PAY_AMT3_new       Default
# ...

# %%
plt.figure(figsize=(15,12))

for i,col in enumerate(pay_amt_cols):    
    plt.subplot(3,2,i + 1)
    cc = sns.countplot(data = df, x = col, hue="Default", palette = 'rocket')
    plt.ylim(0,23000)
    plt.ylabel('')
    plt.tight_layout()
    
    for p in cc.patches:
        cc.annotate((p.get_height()), (p.get_x()+0.05, p.get_height()+800), fontsize=11)    

plt.show()

# %%
plt.figure(figsize=(15,12))

for i,col in enumerate(pay_amt_cols):    
    plt.subplot(3,2,i + 1)
    cc = sns.barplot(x = col, y = "Default", data = df, palette = 'rocket', ci = None)
    plt.ylabel("% of Default", fontsize= 12)
    plt.ylim(0,0.5)
    plt.tight_layout()
    
    for p in cc.patches:
        cc.annotate("%.2f" %(p.get_height()), (p.get_x()+0.25, p.get_height()+0.03),fontsize=13)

plt.show()

# %% [markdown]
# It is clear that the people who have not clear their previuos paymaents have higher  chance of default and
# lower rates among those paid over 25k of NT DOLLARS.

# %%
df.head(10)
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_1  PAY_2  PAY_3  PAY_4  \
# 0   1    20000.0    2          2         1   24      2      2     -1     -1
# 1   2   120000.0    2          2         2   26     -1      2      0      0
# 2   3    90000.0    2          2         2   34      0      0      0      0
# 3   4    50000.0    2          2         1   37      0      0      0      0
# 4   5    50000.0    1          2         1   57     -1      0     -1      0
# 5   6    50000.0    1          1         2   37      0      0      0      0
# 6   7   500000.0    1          1         2   29      0      0      0      0
# 7   8   100000.0    2          2         2   23      0     -1     -1      0
# 8   9   140000.0    2          3         1   28      0      0      2      0
# 9  10    20000.0    1          3         2   35     -2     -2     -2     -2
#
#    ...      BILL_AMT3_new      BILL_AMT4_new      BILL_AMT5_new  \
# 0  ...         (0, 25000]            (-1, 0]            (-1, 0]
# ...

# %%
df.head()
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_1  PAY_2  PAY_3  PAY_4  \
# 0   1    20000.0    2          2         1   24      2      2     -1     -1
# 1   2   120000.0    2          2         2   26     -1      2      0      0
# 2   3    90000.0    2          2         2   34      0      0      0      0
# 3   4    50000.0    2          2         1   37      0      0      0      0
# 4   5    50000.0    1          2         1   57     -1      0     -1      0
#
#    ...  PAY_AMT6  Default    Agegrp        Limitrange  PAY_1_new  PAY_2_new  \
# 0  ...       0.0        1  (20, 25]     (5000, 50000]          2          2
# 1  ...    2000.0        1  (25, 30]  (100000, 150000]         -1          2
# 2  ...    5000.0        0  (30, 35]   (50000, 100000]          0          0
# 3  ...    1000.0        0  (35, 40]     (5000, 50000]          0          0
# 4  ...     679.0        0  (50, 60]     (5000, 50000]         -1          0
#
#    PAY_3_new  PAY_4_new  PAY_5_new  PAY_6_new
# ...

# %%
X1 = df.copy().drop('Default', axis=1)
y = df['Default']

# %%
X1
# Out:
#           ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_1  PAY_2  PAY_3  \
# 0          1    20000.0    2          2         1   24      2      2     -1
# 1          2   120000.0    2          2         2   26     -1      2      0
# 2          3    90000.0    2          2         2   34      0      0      0
# 3          4    50000.0    2          2         1   37      0      0      0
# 4          5    50000.0    1          2         1   57     -1      0     -1
# ...      ...        ...  ...        ...       ...  ...    ...    ...    ...
# 29995  29996   220000.0    1          3         1   39      0      0      0
# 29996  29997   150000.0    1          3         2   43     -1     -1     -1
# 29997  29998    30000.0    1          2         2   37      4      3      2
# 29998  29999    80000.0    1          3         1   41      1     -1      0
# 29999  30000    50000.0    1          2         1   46      0      0      0
#
# ...

# %%
X_base = X1.copy().drop( pay_x_newcol, axis = 1)
X_base = X_base.drop(bill_amt_new, axis = 1)
X_base = X_base.drop(pay_amt_cols, axis = 1)
X_base = X_base.drop(['Agegrp', 'Limitrange','ID'], axis = 1)
X_base
# Out:
#        LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_1  PAY_2  PAY_3  PAY_4  \
# 0        20000.0    2          2         1   24      2      2     -1     -1
# 1       120000.0    2          2         2   26     -1      2      0      0
# 2        90000.0    2          2         2   34      0      0      0      0
# 3        50000.0    2          2         1   37      0      0      0      0
# 4        50000.0    1          2         1   57     -1      0     -1      0
# ...          ...  ...        ...       ...  ...    ...    ...    ...    ...
# 29995   220000.0    1          3         1   39      0      0      0      0
# 29996   150000.0    1          3         2   43     -1     -1     -1     -1
# 29997    30000.0    1          2         2   37      4      3      2     -1
# 29998    80000.0    1          3         1   41      1     -1      0      0
# 29999    50000.0    1          2         1   46      0      0      0      0
#
# ...

# %%
import pickle
from importlib import reload  
from sklearn.ensemble import RandomForestClassifier, VotingClassifier
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score
import logging
logger = logging.getLogger()
fhandler = logging.FileHandler(filename='mylog.log', mode='a')
formatter = logging.Formatter('%(asctime)s - %(name)s - %(levelname)s - %(message)s')
fhandler.setFormatter(formatter)
logger.addHandler(fhandler)
logger.setLevel(logging.DEBUG)
logging.info('The data analysis segment presented in Jupyter Notebook')


X=X_base
y=df['Default']

logging.info("We will be fitting the Model -  Random Forest after using TTS")

# %%
# Splitting data into Train and Cross-validation data 

from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.20)

# %% [markdown]
# RANDOM FOREST MODEL

# %%
rfm = RandomForestClassifier(n_estimators=20,oob_score=True,n_jobs=1,random_state=42,max_features=None,min_samples_leaf=10)
rfm.fit(X_train,y_train)
rfm_y_pred = rfm.predict(X_test)
print(accuracy_score(rfm_y_pred,y_test))
# Out:
# 0.8286666666666667

# %%
print('F1 Score: %.3f' % f1_score(y_test, rfm_y_pred))
# Out:
# F1 Score: 0.503
